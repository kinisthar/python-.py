# %% [markdown]
# # IMPORTANDO empezare con la libreria de pandas y a modelar la información

# %%
import pandas as pd

# %%
df_cardio_base= pd.read_csv("cardio_base.csv")

# %% [markdown]
# YA TRAJO NUESTROS DATOS ASI QUE LO SIGUIENTE ES VER NUESTRO METODO HEAD

# %%
df_cardio_base.head(30)
# Out:
#     id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0    0  18393       2     168    62.0    110     80            1      0
# 1    1  20228       1     156    85.0    140     90            3      0
# 2    2  18857       1     165    64.0    130     70            3      0
# 3    3  17623       2     169    82.0    150    100            1      0
# 4    4  17474       1     156    56.0    100     60            1      0
# 5    8  21914       1     151    67.0    120     80            2      0
# 6    9  22113       1     157    93.0    130     80            3      0
# 7   12  22584       2     178    95.0    130     90            3      0
# 8   13  17668       1     158    71.0    110     70            1      0
# 9   14  19834       1     164    68.0    110     60            1      0
# 10  15  22530       1     169    80.0    120     80            1      0
# 11  16  18815       2     173    60.0    120     80            1      0
# ...

# %% [markdown]
# Ahora mirare el Metodo  SHAPE

# %%
df_cardio_base.shape
# Out:
# (70000, 9)

# %% [markdown]
# Ahora mostrare dos columnas en especifico  para saber la edad y numero de id de los datos y la cantidad

# %%
df_cardio_base[['id','age']]
# Out:
#           id    age
# 0          0  18393
# 1          1  20228
# 2          2  18857
# 3          3  17623
# 4          4  17474
# ...      ...    ...
# 69995  99993  19240
# 69996  99995  22601
# 69997  99996  19066
# 69998  99998  22431
# 69999  99999  20540
#
# [70000 rows x 2 columns]

# %% [markdown]
# con esto estare calculando  el total de las personas que tenfo en mi base de datos con el metodo MEAN

# %%
df_cardio_base['gender'].mean()
# Out:
# 1.3495714285714286

# %% [markdown]
# La funcion DESCRIBE para nuestras estadisticas

# %%
df_cardio_base['weight'].describe
# Out:
# <bound method NDFrame.describe of 0         62.0
# 1         85.0
# 2         64.0
# 3         82.0
# 4         56.0
#          ...
# 69995     76.0
# 69996    126.0
# 69997    105.0
# 69998     72.0
# 69999     72.0
# Name: weight, Length: 70000, dtype: float64>

# %% [markdown]
# # igual un resumen de nuestra DATA

# %%
df_cardio_base.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol         smoke
# count  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      0.088129
# std      154.011419    188.472530      0.680250      0.283484
# ...

# %%
var = 'age'

# %%
data = pd.concat([df_cardio_base['height'],df_cardio_base[var]],axis =1)

# %%
data.head(20)
# Out:
#     height    age
# 0      168  18393
# 1      156  20228
# 2      165  18857
# 3      169  17623
# 4      156  17474
# 5      151  21914
# 6      157  22113
# 7      178  22584
# 8      158  17668
# 9      164  19834
# 10     169  22530
# 11     173  18815
# 12     165  14791
# 13     158  19809
# 14     181  14532
# 15     172  16782
# 16     170  21296
# 17     158  16747
# 18     154  17482
# 19     162  21755

# %%
data.plot.scatter(x=var,y= 'height', ylim = (0,180))
# Out:
# <AxesSubplot:xlabel='age', ylabel='height'>

# %%
var = 'weight'
data = pd.concat([df_cardio_base['height'],df_cardio_base[var]],axis=1)
data.plot.scatter(x=var, y='height', ylim = (0,80))
# Out:
# <AxesSubplot:xlabel='weight', ylabel='height'>

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set(font_scale=2)
sns.set_style('whitegrid')

# %%
var = 'ap_hi'
data = pd.concat([df_cardio_base['ap_lo'],df_cardio_base[var]],axis=1)

# %%
data.head(20)
# Out:
#     ap_lo  ap_hi
# 0      80    110
# 1      90    140
# 2      70    130
# 3     100    150
# 4      60    100
# 5      80    120
# 6      80    130
# 7      90    130
# 8      70    110
# 9      60    110
# 10     80    120
# 11     80    120
# 12     80    120
# 13     70    110
# 14     90    130
# 15     80    120
# 16     70    130
# 17     70    110
# 18     70    100
# 19     70    120

# %%
f,ax = plt.subplots(figsize=(8,9))
fig = sns.boxplot(x=var, y = 'ap_lo', data = data)
fig.axis(ymin = 0, ymax = 80)
# Out:
# (-0.5, 152.5, 0.0, 80.0)
